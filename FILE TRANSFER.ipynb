# %%
import http.server
import socketserver
PORT = 8000
handler = http.server.SimpleHTTPRequestHandler
with socketserver.TCPServer(("", PORT ), handler)as http:
    print ("Server runnin on port ", PORT)
    http.serve_forever()
# Out:
# Server runnin on port  8000
